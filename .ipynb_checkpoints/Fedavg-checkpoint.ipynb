# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from tqdm import tqdm
import copy
import matplotlib 
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1)
        self.fc1 = nn.Linear(2048, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.conv3(x)
        x = F.relu(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        output = F.log_softmax(x, dim=1)
        return output


def client_update(client_model, optimizer, train_loader, epoch):
    client_model.train()
    for e in range(epoch):
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.cuda(), target.cuda()
            optimizer.zero_grad()
            output = client_model(data)
            loss = F.nll_loss(output, target)/epoch
            loss.backward()
            optimizer.step()
    return loss.item()

def server_aggregate(global_model, client_models):
    global_dict = global_model.state_dict()
    for k in global_dict.keys():
        global_dict[k] = torch.stack([client_models[i].state_dict()[k] for i in range(len(client_models))], 0).mean(0)
    global_model.load_state_dict(global_dict)
    for model in client_models:
        model.load_state_dict(global_model.state_dict())

def test(global_model, test_loader):
    global_model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.cuda(), target.cuda()
            output = global_model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    acc = correct / len(test_loader.dataset)

    return test_loss, acc

# %%
# NON-IID case: every client has images of two categories chosen from [0, 1], [2, 3], [4, 5], [6, 7], or [8, 9].

# Hyperparameters

num_clients = 100
num_selected = 10
num_rounds = 100
epochs = 10
batch_size = 32
local_ep_list = np.random.choice(range(1,epochs+1),size=num_clients)
lr = 0.01
# Creating decentralized datasets

traindata = datasets.MNIST('./data', train=True, download=True,
                       transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,))])
                       )
target_labels = torch.stack([traindata.targets == i for i in range(10)])
target_labels_split = []
for i in range(5):
    target_labels_split += torch.split(torch.where(target_labels[(2 * i):(2 * (i + 1))].sum(0))[0], int(60000 / num_clients))
traindata_split = [torch.utils.data.Subset(traindata, tl) for tl in target_labels_split]
train_loader = [torch.utils.data.DataLoader(x, batch_size=batch_size, shuffle=True) for x in traindata_split]

test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('./data', train=False, transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,))])
        ), batch_size=batch_size, shuffle=True)

# Instantiate models and optimizers

global_model = Net().cuda()
client_models = [Net().cuda() for _ in range(num_selected)]
for model in client_models:
    model.load_state_dict(global_model.state_dict())
# print(global_model.state_dict())


opt = [optim.SGD(model.parameters(), lr=lr) for model in client_models]

# Runnining FL
test_loss_accu = []
acc_accu = []
for r in range(num_rounds):
    # select random clients
    client_idx = np.random.permutation(num_clients)[:num_selected]

    # client update
    loss = 0
    for i in range(num_selected):
        loss += client_update(client_models[i], opt[i], train_loader[client_idx[i]], epoch=int(local_ep_list[client_idx[i]]))
    
    # serer aggregate
    server_aggregate(global_model, client_models)
    test_loss, acc = test(global_model, test_loader)
    test_loss_accu.append(test_loss)
    acc_accu.append(acc)
    
    print('%d-th round' % r)
    print('average train loss %0.3g | test loss %0.3g | test acc: %0.3f' % (loss / num_selected, test_loss, acc))
    
file_name = './save/objects/fed_diffEpoch{}_lr{}_loss_and_acc.pkl'. \
                format(epochs, lr)
with open(file_name, 'wb') as f:
            pickle.dump([test_loss_accu, acc_accu.append], f)
    
# Plot Average Accuracy vs Communication rounds
plt.figure()
plt.title('Accuracy vs Communication rounds')
plt.plot(range(len(acc_accu)), acc_accu, color='k')
plt.ylabel('Accuracy')
plt.xlabel('Communication Rounds')
plt.savefig('./save/fed_diffEpoch{}_lr{}_acc.png'.
                format(epochs, lr))
# Out:
# 0-th round
# average train loss 0.818 | test loss 2.3 | test acc: 0.118
# 1-th round
# average train loss 0.851 | test loss 2.29 | test acc: 0.146
# 2-th round
# average train loss 0.316 | test loss 2.28 | test acc: 0.098
# 3-th round
# average train loss 0.435 | test loss 2.28 | test acc: 0.200
# 4-th round
# average train loss 0.167 | test loss 2.35 | test acc: 0.182
# 5-th round
# average train loss 0.208 | test loss 2.38 | test acc: 0.365
# 6-th round
# average train loss 0.0822 | test loss 2.3 | test acc: 0.378
# 7-th round
# average train loss 0.176 | test loss 2.01 | test acc: 0.493
# 8-th round
# average train loss 0.0312 | test loss 2.79 | test acc: 0.179
# 9-th round
# average train loss 0.109 | test loss 1.93 | test acc: 0.405
# 10-th round
# average train loss 0.0361 | test loss 1.76 | test acc: 0.454
# 11-th round
# average train loss 0.031 | test loss 1.7 | test acc: 0.417
# 12-th round
# average train loss 0.0814 | test loss 1.62 | test acc: 0.444
# 13-th round
# average train loss 0.112 | test loss 1.66 | test acc: 0.340
# 14-th round
# average train loss 0.0353 | test loss 1.5 | test acc: 0.570
# 15-th round
# average train loss 0.0644 | test loss 1.49 | test acc: 0.466
# 16-th round
# average train loss 0.0275 | test loss 1.27 | test acc: 0.564
# 17-th round
# average train loss 0.0393 | test loss 1.56 | test acc: 0.330
# 18-th round
# average train loss 0.02 | test loss 1.13 | test acc: 0.646
# 19-th round
# average train loss 0.0262 | test loss 1.04 | test acc: 0.726
# 20-th round
# average train loss 0.0193 | test loss 1.34 | test acc: 0.568
# 21-th round
# average train loss 0.0432 | test loss 1.36 | test acc: 0.486
# 22-th round
# average train loss 0.0956 | test loss 1.43 | test acc: 0.474
# 23-th round
# average train loss 0.0627 | test loss 1.06 | test acc: 0.628
# 24-th round
# average train loss 0.0381 | test loss 1.49 | test acc: 0.418
# 25-th round
# average train loss 0.045 | test loss 1.01 | test acc: 0.668
# 26-th round
# average train loss 0.0164 | test loss 1.04 | test acc: 0.657
# 27-th round
# average train loss 0.016 | test loss 1.64 | test acc: 0.468
# 28-th round
# average train loss 0.00938 | test loss 0.948 | test acc: 0.691
# 29-th round
# average train loss 0.0352 | test loss 0.94 | test acc: 0.674
# 30-th round
# average train loss 0.0428 | test loss 1.1 | test acc: 0.591
# 31-th round
# average train loss 0.0172 | test loss 1.13 | test acc: 0.572
# 32-th round
# average train loss 0.0172 | test loss 1.21 | test acc: 0.593
# 33-th round
# average train loss 0.00587 | test loss 0.993 | test acc: 0.660
# 34-th round
# average train loss 0.0276 | test loss 0.928 | test acc: 0.689
# 35-th round
# average train loss 0.0262 | test loss 1.06 | test acc: 0.596
# 36-th round
# average train loss 0.0108 | test loss 0.903 | test acc: 0.700
# 37-th round
# average train loss 0.0236 | test loss 0.967 | test acc: 0.630
# 38-th round
# average train loss 0.0208 | test loss 0.879 | test acc: 0.690
# 39-th round
# average train loss 0.0246 | test loss 1.08 | test acc: 0.592
# 40-th round
# average train loss 0.0194 | test loss 0.763 | test acc: 0.762
# 41-th round
# average train loss 0.00969 | test loss 0.939 | test acc: 0.659
# 42-th round
# average train loss 0.0101 | test loss 1.44 | test acc: 0.507
# 43-th round
# average train loss 0.0257 | test loss 1.14 | test acc: 0.615
# 44-th round
# average train loss 0.00902 | test loss 1.3 | test acc: 0.553
# 45-th round
# average train loss 0.0171 | test loss 0.715 | test acc: 0.789
# 46-th round
# average train loss 0.00811 | test loss 1.1 | test acc: 0.614
# 47-th round
# average train loss 0.0284 | test loss 0.749 | test acc: 0.750
# 48-th round
# average train loss 0.0315 | test loss 0.895 | test acc: 0.686
# 49-th round
# average train loss 0.019 | test loss 0.792 | test acc: 0.720
# 50-th round
# average train loss 0.0224 | test loss 0.708 | test acc: 0.784
# 51-th round
# average train loss 0.00705 | test loss 0.944 | test acc: 0.668
# 52-th round
# average train loss 0.0241 | test loss 0.708 | test acc: 0.777
# 53-th round
# average train loss 0.0195 | test loss 0.84 | test acc: 0.702
# 54-th round
# average train loss 0.012 | test loss 0.974 | test acc: 0.649
# 55-th round
# average train loss 0.015 | test loss 0.785 | test acc: 0.727
# 56-th round
# average train loss 0.0129 | test loss 0.737 | test acc: 0.751
# 57-th round
# average train loss 0.0756 | test loss 1.39 | test acc: 0.479
# 58-th round
# average train loss 0.00722 | test loss 1.14 | test acc: 0.621
# 59-th round
# average train loss 0.033 | test loss 0.755 | test acc: 0.750
# 60-th round
# average train loss 0.0132 | test loss 0.864 | test acc: 0.716
# 61-th round
# average train loss 0.0337 | test loss 0.917 | test acc: 0.678
# 62-th round
# average train loss 0.0359 | test loss 0.891 | test acc: 0.678
# 63-th round
# average train loss 0.132 | test loss 0.845 | test acc: 0.676
# 64-th round
# average train loss 0.00555 | test loss 0.73 | test acc: 0.755
# 65-th round
# average train loss 0.0149 | test loss 0.84 | test acc: 0.712
# 66-th round
# average train loss 0.0169 | test loss 0.871 | test acc: 0.686
# 67-th round
# average train loss 0.026 | test loss 0.909 | test acc: 0.692
# 68-th round
# average train loss 0.0292 | test loss 0.866 | test acc: 0.707
# 69-th round
# average train loss 0.0119 | test loss 0.754 | test acc: 0.739
# 70-th round
# average train loss 0.0659 | test loss 1.08 | test acc: 0.566
# 71-th round
# average train loss 0.00729 | test loss 0.688 | test acc: 0.765
# 72-th round
# average train loss 0.0109 | test loss 0.806 | test acc: 0.711
# 73-th round
# average train loss 0.00865 | test loss 0.65 | test acc: 0.791
# 74-th round
# average train loss 0.0361 | test loss 0.687 | test acc: 0.760
# 75-th round
# average train loss 0.022 | test loss 0.631 | test acc: 0.789
# 76-th round
# average train loss 0.00275 | test loss 0.732 | test acc: 0.755
# 77-th round
# average train loss 0.00493 | test loss 0.945 | test acc: 0.670
# 78-th round
# average train loss 0.0106 | test loss 0.692 | test acc: 0.773
# 79-th round
# average train loss 0.0281 | test loss 0.794 | test acc: 0.716
# 80-th round
# average train loss 0.0102 | test loss 0.697 | test acc: 0.771
# 81-th round
# average train loss 0.0293 | test loss 0.811 | test acc: 0.726
# 82-th round
# average train loss 0.0229 | test loss 1.07 | test acc: 0.608
# 83-th round
# average train loss 0.0233 | test loss 0.639 | test acc: 0.778
# 84-th round
# average train loss 0.0024 | test loss 0.599 | test acc: 0.809
# 85-th round
# average train loss 0.00721 | test loss 0.567 | test acc: 0.817
# 86-th round
# average train loss 0.0342 | test loss 0.698 | test acc: 0.757
# 87-th round
# average train loss 0.00502 | test loss 0.592 | test acc: 0.801
# 88-th round
# average train loss 0.0125 | test loss 0.633 | test acc: 0.791
# 89-th round
# average train loss 0.0378 | test loss 0.82 | test acc: 0.685
# 90-th round
# average train loss 0.00976 | test loss 0.564 | test acc: 0.825
# 91-th round
# average train loss 0.00507 | test loss 0.776 | test acc: 0.726
# 92-th round
# average train loss 0.0211 | test loss 0.606 | test acc: 0.795
# 93-th round
# average train loss 0.0127 | test loss 0.677 | test acc: 0.758
# 94-th round
# average train loss 0.00524 | test loss 0.73 | test acc: 0.733
# 95-th round
# average train loss 0.00485 | test loss 0.715 | test acc: 0.747
# 96-th round
# average train loss 0.0379 | test loss 0.831 | test acc: 0.731
# 97-th round
# average train loss 0.019 | test loss 0.651 | test acc: 0.771
# 98-th round
# average train loss 0.0645 | test loss 0.723 | test acc: 0.750
# 99-th round
# average train loss 0.0179 | test loss 0.644 | test acc: 0.779
# 100-th round
# average train loss 0.00667 | test loss 0.593 | test acc: 0.806
# 101-th round
# average train loss 0.0129 | test loss 0.689 | test acc: 0.752
# 102-th round
# average train loss 0.0305 | test loss 0.499 | test acc: 0.849
# 103-th round
# average train loss 0.00403 | test loss 0.668 | test acc: 0.772
# 104-th round
# average train loss 0.00361 | test loss 0.797 | test acc: 0.721
# 105-th round
# average train loss 0.0211 | test loss 0.638 | test acc: 0.770
# 106-th round
# average train loss 0.00877 | test loss 0.658 | test acc: 0.765
# 107-th round
# average train loss 0.00772 | test loss 0.685 | test acc: 0.754
# 108-th round
# average train loss 0.00962 | test loss 0.642 | test acc: 0.776
# 109-th round
# average train loss 0.00835 | test loss 0.896 | test acc: 0.658
# 110-th round
# average train loss 0.00534 | test loss 0.914 | test acc: 0.678
# 111-th round
# average train loss 0.00932 | test loss 0.694 | test acc: 0.758
# 112-th round
# average train loss 0.00795 | test loss 0.698 | test acc: 0.755
# 113-th round
# average train loss 0.0107 | test loss 0.582 | test acc: 0.806
# 114-th round
# average train loss 0.00959 | test loss 0.595 | test acc: 0.806
# 115-th round
# average train loss 0.0026 | test loss 0.705 | test acc: 0.738
# 116-th round
# average train loss 0.0429 | test loss 1.31 | test acc: 0.618
# 117-th round
# average train loss 0.0109 | test loss 0.784 | test acc: 0.730
# 118-th round
# average train loss 0.0098 | test loss 0.871 | test acc: 0.717
# 119-th round
# average train loss 0.00376 | test loss 1.1 | test acc: 0.633
# 120-th round
# average train loss 0.00351 | test loss 0.655 | test acc: 0.777
# 121-th round
# average train loss 0.00583 | test loss 0.511 | test acc: 0.838
# 122-th round
# average train loss 0.216 | test loss 0.551 | test acc: 0.807
# 123-th round
# average train loss 0.00682 | test loss 0.575 | test acc: 0.800
# 124-th round
# average train loss 0.0119 | test loss 0.78 | test acc: 0.736
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-cb2b9f884509> in <module>
#      47     loss = 0
#      48     for i in range(num_selected):
# ---> 49         loss += client_update(client_models[i], opt[i], train_loader[client_idx[i]], epoch=int(local_ep_list[client_idx[i]]))
#      50
#      51     # serer aggregate
#
# <ipython-input-18-de660702dea9> in client_update(client_model, optimizer, train_loader, epoch)
#      39     client_model.train()
#      40     for e in range(epoch):
# ---> 41         for batch_idx, (data, target) in enumerate(train_loader):
#      42             data, target = data.cuda(), target.cuda()
#      43             optimizer.zero_grad()
#
# D:\anacondainstall\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# D:\anacondainstall\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# D:\anacondainstall\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# D:\anacondainstall\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# D:\anacondainstall\lib\site-packages\torch\utils\data\dataset.py in __getitem__(self, idx)
#     270
#     271     def __getitem__(self, idx):
# --> 272         return self.dataset[self.indices[idx]]
#     273
#     274     def __len__(self):
#
# D:\anacondainstall\lib\site-packages\torchvision\datasets\mnist.py in __getitem__(self, index)
#     104
#     105         if self.transform is not None:
# --> 106             img = self.transform(img)
#     107
#     108         if self.target_transform is not None:
#
# D:\anacondainstall\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#      65     def __call__(self, img):
#      66         for t in self.transforms:
# ---> 67             img = t(img)
#      68         return img
#      69
#
# D:\anacondainstall\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, pic)
#     102             Tensor: Converted image.
#     103         """
# --> 104         return F.to_tensor(pic)
#     105
#     106     def __repr__(self):
#
# D:\anacondainstall\lib\site-packages\torchvision\transforms\functional.py in to_tensor(pic)
#      96         img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
#      97
# ---> 98     img = img.view(pic.size[1], pic.size[0], len(pic.getbands()))
#      99     # put it from HWC to CHW format
#     100     img = img.permute((2, 0, 1)).contiguous()
#
# KeyboardInterrupt:
